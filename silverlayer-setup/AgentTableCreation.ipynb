# %%
dbutils.fs.ls("abfss://silverlayer@policysysadls.dfs.core.windows.net/")

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS silverlayer LOCATION 'abfss://silverlayer@policysysadls.dfs.core.windows.net/'

# %%
# %sql
create or replace table silverlayer.Agent(
agent_id integer, agent_name string, agent_email string, agent_phone string, branch_id integer, create_timestamp timestamp,merged_timestamp timestamp
) USING DELTA LOCATION "abfss://silverlayer@policysysadls.dfs.core.windows.net/Agent"

# %%
# %sql
select * from silverlayer.Agent
