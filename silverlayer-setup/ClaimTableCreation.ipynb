# %%
# %sql
select* from bronzelayer.claim

# %%
# %sql
CREATE OR REPLACE TABLE silverlayer.Claim(
claim_id integer,
policy_id integer,
date_of_claim date,
claim_amount decimal(18,0),
claim_status string,
LastUpdatedTimeStamp timestamp,
merged_timestamp timestamp
)USING DELTA LOCATION "abfss://silverlayer@policysysadls.dfs.core.windows.net/Claim"
