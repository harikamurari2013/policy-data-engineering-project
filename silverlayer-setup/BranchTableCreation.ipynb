# %%
# %sql
CREATE OR REPLACE table silverlayer.Branch(
  branch_id INT,
  branch_country string,
  branch_city string,
  merged_timestamp timestamp
) USING DELTA LOCATION "abfss://silverlayer@policysysadls.dfs.core.windows.net/Branch"

# %%
# %sql
select * from silverlayer.branch
