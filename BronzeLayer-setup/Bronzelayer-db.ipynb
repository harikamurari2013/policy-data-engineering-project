# %%
# %sql
CREATE DATABASE IF NOT EXISTS bronzelayer
LOCATION 'abfss://bronzelayer@policysysadls.dfs.core.windows.net/';

# %%
# %sql
use bronzelayer;
show tables;

# %%
# %sql
DROP DATABASE IF EXISTS bronze;

# %%
# %sql
SHOW DATABASES;

# %%
# %sql
use bronzelayer;
select current_database()
