# %%
from pyspark.sql.functions import lit
claim_schema = "claim_id int, policy_id int, date_of_claim timestamp, claim_amount double, claim_status string, LastUpdatedTimeStamp timestamp"
df = spark.read.parquet("abfss://landing@policysysadls.dfs.core.windows.net/ClaimData/*.parquet", inferSchema=False, schema=claim_schema)
df_merge_flag = df.withColumn("merge_flag", lit(False))
df_merge_flag.write.option("path", "abfss://bronzelayer@policysysadls.dfs.core.windows.net/Claim").mode("append").saveAsTable("bronzelayer.Claim")

# %%
# %sql
select * from bronzelayer.Claim;

# %%
from datetime import datetime
def getFilePathWithDates(filePath):
    # get the current time in mm-dd-yyyy format
    current_time = datetime.now().strftime('%m-%d-%Y')
    new_file_path = filePath+'/'+current_time
    return new_file_path

# %%
dbutils.fs.mv("abfss://landing@policysysadls.dfs.core.windows.net/ClaimData/",getFilePathWithDates("abfss://processed@policysysadls.dfs.core.windows.net/ClaimData/"),True)
